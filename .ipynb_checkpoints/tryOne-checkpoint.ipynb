# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv('Data/Traffic_Data_3.csv')

# %%
df.head()
# Out:
#          Date Road/Intersection Name  Traffic Volume  Average Speed  \
# 0  01-01-2022      Kalina Kurla Road        0.394691       0.000000
# 1         NaN              CST Road         0.232048       0.138486
# 2         NaN     Road no. 01, TPS V        0.333274       0.289923
# 3  01-01-2022   Vakola Pipeline Road        0.622414       0.134711
# 4  01-01-2022        St Anthony Road        0.602303       0.369206
#
#    Travel Time Index  Congestion Level  Road Capacity Utilization  \
# 0           0.939567          0.506610                        NaN
# 1           0.366939          0.520000                   0.217400
# 2           0.185031          0.312639                   0.650560
# 3           0.596512               NaN                   0.951606
# 4                NaN          0.309344                   0.637379
#
#    Incident Reports  Environmental Impact  Public Transport Usage  \
# 0               0.8              0.160889                0.854954
# 1               0.2              0.300819                0.970027
# 2               0.0              0.424564                0.867435
# 3               0.8              0.303636                0.253161
# 4               0.4              0.205700                0.734581
#
#    Traffic Signal Compliance  Parking Usage  Pedestrian and Cyclist Count  \
# 0                   0.874981       0.821369                      0.772152
# 1                   0.494275            NaN                      0.518987
# 2                   0.409401       0.339658                      0.727848
# 3                   0.621091       0.228394                      0.202532
# 4                   0.048124       0.047132                      0.848101
#
#   Weather Conditions  Roadwork and Construction Activity
# 0               Mild                                 1.0
# 1               Mild                                 NaN
# 2               Mild                                 0.0
# 3               Mild                                 1.0
# 4               Mild                                 1.0

# %%
df.isnull().sum()
# Out:
# Date                                  10142
# Road/Intersection Name                10095
# Traffic Volume                        10158
# Average Speed                         10139
# Travel Time Index                     10050
# Congestion Level                       9965
# Road Capacity Utilization             10103
# Incident Reports                       9835
# Environmental Impact                  10103
# Public Transport Usage                10044
# Traffic Signal Compliance             10182
# Parking Usage                         10073
# Pedestrian and Cyclist Count           9974
# Weather Conditions                    10128
# Roadwork and Construction Activity    10130
# dtype: int64

# %%
df.shape
# Out:
# (105850, 15)

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_22416\8428392.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Forward fill for missing values, if any

# %%
df.isnull().sum()
# Out:
# Date                                  0
# Road/Intersection Name                0
# Traffic Volume                        0
# Average Speed                         0
# Travel Time Index                     0
# Congestion Level                      0
# Road Capacity Utilization             1
# Incident Reports                      0
# Environmental Impact                  0
# Public Transport Usage                0
# Traffic Signal Compliance             0
# Parking Usage                         0
# Pedestrian and Cyclist Count          0
# Weather Conditions                    0
# Roadwork and Construction Activity    0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105850 entries, 0 to 105849
# Data columns (total 15 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Date                                105850 non-null  object
#  1   Road/Intersection Name              105850 non-null  object
#  2   Traffic Volume                      105850 non-null  float64
#  3   Average Speed                       105850 non-null  float64
#  4   Travel Time Index                   105850 non-null  float64
#  5   Congestion Level                    105850 non-null  float64
#  6   Road Capacity Utilization           105849 non-null  float64
#  7   Incident Reports                    105850 non-null  float64
#  8   Environmental Impact                105850 non-null  float64
#  9   Public Transport Usage              105850 non-null  float64
#  10  Traffic Signal Compliance           105850 non-null  float64
#  11  Parking Usage                       105850 non-null  float64
#  12  Pedestrian and Cyclist Count        105850 non-null  float64
#  13  Weather Conditions                  105850 non-null  object
#  14  Roadwork and Construction Activity  105850 non-null  float64
# dtypes: float64(12), object(3)
# memory usage: 12.1+ MB
# None

# %%
print(df.describe())
# Out:
#        Traffic Volume  Average Speed  Travel Time Index  Congestion Level  \
# count   105850.000000  105850.000000      105850.000000     105850.000000
# mean         0.520138       0.116987           0.482059          0.549622
# std          0.197498       0.192660           0.212898          0.265944
# min          0.000000       0.000000           0.000000          0.000000
# 25%          0.363869       0.000000           0.326310          0.330000
# 50%          0.520929       0.000000           0.482631          0.550096
# 75%          0.677302       0.185868           0.639184          0.780000
# max          1.000000       1.000000           1.000000          1.000000
#
#        Road Capacity Utilization  Incident Reports  Environmental Impact  \
# count              105849.000000     105850.000000         105850.000000
# mean                    0.498713          0.425068              0.288518
# std                     0.288778          0.290703              0.149155
# min                     0.000000          0.000000              0.000000
# 25%                     0.248268          0.200000              0.162375
# 50%                     0.498376          0.400000              0.288354
# 75%                     0.748536          0.600000              0.413346
# max                     1.000000          1.000000              1.000000
#
#        Public Transport Usage  Traffic Signal Compliance  Parking Usage  \
# count           105850.000000              105850.000000  105850.000000
# mean                 0.498188                   0.499882       0.499382
# std                  0.288977                   0.288591       0.289488
# min                  0.000000                   0.000000       0.000000
# 25%                  0.247613                   0.249552       0.247092
# 50%                  0.495880                   0.501908       0.499390
# 75%                  0.749166                   0.749223       0.748793
# max                  1.000000                   1.000000       1.000000
#
#        Pedestrian and Cyclist Count  Roadwork and Construction Activity
# count                 105850.000000                       105850.000000
# mean                       0.499543                            0.497685
# std                        0.213056                            0.499997
# min                        0.000000                            0.000000
# 25%                        0.341772                            0.000000
# 50%                        0.500000                            0.000000
# 75%                        0.658228                            1.000000
# max                        1.000000                            1.000000

# %%
print(df['Weather Conditions'].unique())
# Out:
# ['Mild' 'Fog' 'Clear' 'Heatwave' 'Hot and Humid' 'Rainy' 'Thunderstorm']

# %%
print(df['Road/Intersection Name'].nunique())
print(df['Road/Intersection Name'].unique())
# Out:
# 283
# ['Kalina Kurla Road' 'CST Road ' 'Road no. 01, TPS V'
#  'Vakola Pipeline Road' 'St Anthony Road' 'Mahalaxmi Mandir Road'
#  'Rajendra Kamble Road' 'New English School Marg' 'Samaj Mandir Hall Marg'
#  'J L Shirshekar Marg' 'Road no. 07, TPS III' 'Road No. 06, TPS III'
#  'Road No. 04, TPS III' 'Road no. 11, TPS V' 'Ram Mandir Road'
#  'Military Camp Road' 'Side strips of Jawaharlal Nehru Road'
#  'Vijay Nagar Road' 'Chhatrapati Shivaji Maharaj Road Extn.'
#  'Parshiwadi Road' 'Manipada Road' 'Shardadevi Marg'
#  'Road no. 08, TPS III' 'Takshila Marg' 'Dnyaneshwar Mandir Marg'
#  'Abbasaheb Shinde Marg' 'Sunder Nagar Road no. 01'
#  'Sunder Nagar Road no. 03' 'Ramanath Parkar Marg' 'Khernagar Road no. 01'
#  'Khernagar Road no. 03' 'Khernagar Road no. 04' 'Khernagar Road no. 06'
#  'Khernagar Road no. 07' 'Khernagar Road no. 08' 'V.M. Bhargav Road'
#  'Sidestrip of Juhu Road' 'SS of Kanubhai Desai Marg'
#  '11th Road, Khar West ' '14th B Road, Khar(W)' 'Gurugangeshwar Road'
#  '10th Road' 'Main Avenue Road' 'R K Mission Road'
#  'S B Patil Road , Khar (W)' '30th Road' '24th Road(St Theresa Road)'
#  '3rd road (Y Shape)' 'Turner Road-R K Patkar Road Junction'
#  'Tiurner Road- Ambedkar Road Junction' '2nd Hasnabad Road'
#  'Dr Peter Dias Road' 'SS of K C Marg' 'St Peter Road'
#  '14th Road, Bandra (W)' '12th Road' 'Side Strip of Dr Ambedkar road'
#  'Side Strip of Manuel Gonsalves Road' 'Side Strip C D Road' '27th Road'
#  '28th Road' 'New Kantwadi Road' 'National Library Road'
#  'Jain Derasar Road' 'Road No 5, Rizvi complex' 'Pali Mala Road'
#  '16th Road Khar West' '15th road' '7th road, Khar' 'Talmiki Road '
#  'P M Road' '17th Road (Santacruz)' 'Saibaba Marg'
#  'St. Andrews Road Extention ' 'Anthony Road' 'St. John Road Extention'
#  ' SS Waterfield Road' 'Juhu Road Link Road Junction' 'Dattatray Road'
#  'Poddar Road' '5th Rd(Khar)' 'John Baptista Road' 'Jari Mari Road'
#  'V M Bhargav Cross road' '1st Road(IPS) ' 'West Avenue' 'Cyril Rd Exten'
#  'SS 33rd Road' 'St Martin road' 'SS  of RK Mission Road ' 'East Avenue'
#  'Centrel Avenue' 'SS Relief Road ' 'Tarun Bharat Road' 'Off Nehru Road'
#  'Dixit Road' 'Malviya Cross Road ' 'Chimat Pada Road' 'Parleshwar Road'
#  'Prarthana Samaj Cross Road ' 'Dayaldas Main Road ( Part 1)'
#  'Dayaldas Main Road ( Part 2)' 'Parshiwadi Cemetry Road' 'Lelewadi Road'
#  'Nicolaswadi  Rd Side strip' 'N S Phadke Marg ( Side Strip)'
#  'MIDC A Cross Road ' 'Midc Road No. 11' 'N P Thakkar Road'
#  'Veer Makrand Ghanekar Marg' 'Baji Prabhu Deshpande Marg' 'Sahakar Road'
#  'Jeevan Vikas Kendra Marg' 'G. B. Indulakar Marg'
#  'Rammandir  Road Vile Parle' 'Tilak Mandir Road Vile Parle'
#  'Sant janabai X Road' 'Kanoji Angre Marg' 'Sant Chokha Mela Marg'
#  'Charatsingh Colony ' 'off Military Road ' 'Mongibai Road Vile Parle'
#  'MIDC Road no 7' 'Subhash cross Road' 'Sai Nagar Road'
#  'Ramabai Chemburkar Marg' 'Tejpal Scheme Road no 2'
#  'Tejpal Scheme Road no 3' 'Thanawala lane' 'Sahar Road Side Strip'
#  'Subhash Road Side Strip' 'Play Ground Road Vile Parle'
#  'Nariman cross Road' 'Wadarwada Road' 'M.G.Road side strip'
#  'Jiva Mahale Marg Side strip ' 'Shahaji Raje Marg Side strip'
#  'Old Nagardas Rd Side strip' 'Sadbhakiti road ' 'Jogeshwari Gumpha road'
#  'Church Road (Main)' 'Rane Bunglow junction Road'
#  'Road from Mogaveera Bank to Moonlight Dairy' 'Manjrekar wadi Road'
#  'Subhash Nagar 13.40 m D.P.Road Jogeshwari'
#  'Road from Infant School to Apna Ghar Society' 'Dattaram Waikar Marg'
#  'R K Singh Road' 'Natwar Nagar Road no 5' 'Natwar nagar Road no 1'
#  'Guru Govind Singh Road ( Roof Top Society)' 'New Nagardas Road '
#  'Telly Gully Cross Road' 'Bima Nagar Road' 'Kondivita Road'
#  'MIDC Road no 16' 'MIDC Road no 14' 'Kadamwadi Road'
#  'Azad Road,Verma Nagar Road Gundavli' 'Amartaru Road'
#  'Marol Maroshi Road' 'Sarvodaya nagar Road,Guru Govind singh Road '
#  'Extension' 'A N Tiwari Road' 'Gaonthan Road Marol'
#  'Lok Rounak Road Marol' 'Pimpleshwar Mahadev Mandir Marg'
#  'Jogeshwari Gunfa Road Side strip' 'Shivneri Vasahat cross Road'
#  'Mulund Railway Station West ' 'Mulund BMC Garden Lane '
#  'Duncan Company ' 'Mulund Goregaon Link Road' 'Shreyas Signal '
#  'Trinity Circle' 'Anil Kumble Circle' 'G R jolly marg ' 'Ankur Hospital '
#  '100 Feet Road' 'Crompton Greaves' 'Bhandup Station East '
#  'Nahur Railway Station East' 'Hema Park' ' Goregaon Link Road'
#  'Merind Company ' 'Hebbal Flyover' 'Fortis Hospital '
#  'Dr K B Hedgewar Chowk ' 'Ralli wolf ' 'Johnson and Johnson Company '
#  'ESIS Hospital ' 'Govardhan Nagar' 'Maharana Pratap chowk '
#  'Wagle Ward Committee' 'Kisan Nagar junction ' 'Wagle Circle '
#  'Dnyan Sarita Thane' 'Marathahalli Bridge' 'pipe line '
#  'Post and Telegraphs ' 'Vidyaben Gardi School Keshavpada'
#  'Kalidas natyagruh' 'Maharishi Arvind Chowk ' 'Gyan Sarita School '
#  'Kadam Pada' 'Agarwal Municipal hospital ' 'Veena Nagar '
#  'Mukund company ' 'Guru Nanak Nagar ' 'Chirag nagar ' 'Nityanand Nagar '
#  'Laxmi Nagar ' 'Pantnagar ' 'Jija mata bhosle marg junction '
#  'Sarvodaya Hospital ' 'Gopal Bhavan ' 'Amar Mahal ' 'Pestam Sagar '
#  'Somaiya College ' 'Sindhuwadi ' 'Rajawadi Hospital ' 'Gandhi market '
#  'Old Agra Road ' 'Sheetal Cinema ' 'State Bank kamani ' 'PWD office'
#  'Narayan Nagar ' 'Phoenix Market city ' 'Jarimari ' 'Chandivali '
#  'Saikana Bus Station' 'Andheri-Ghatkopar link rd' 'bhatwadi '
#  'Azad Nagar ' 'Maneklal Estate ' 'KajuPada' '90 feet road'
#  'Shivaji Nagar' 'KajuPada pipeline road' 'Agastya Corporate Park '
#  'Piramal Reality Estate ' 'Jagdusha Nagar ' 'Hingwala Lane '
#  'Lavender Baug ' 'Garodia Ngar ' 'Tilak Nagar' 'Ambedkar Garden '
#  'Eastern Express Freeway ' 'Express Highway ' 'Postal Colony '
#  'SG Barve Road Junction ' 'Thakkar Bappa Colony ' 'Nehru Nagr '
#  "Sant Mary's Road" 'Chetana College Road' 'Khar Pipeline Road'
#  'Aaram Society Road' 'Sunder Nagar Road no. 02' 'Bhai Tambe Marg'
#  'Slaughter House Road' '14th Road Khar' 'M G Road ' '13th Road'
#  'Dr Ambedkar Road ' 'MIDC B X Road' 'Nanda Patkar Marg'
#  'Tilak Vidyalaya Road' 'MIDC road no 23 (Ext. C x Road)'
#  'Mahakali Caves Road' 'Mogra Service Road' 'S.R. Mahadik Road'
#  'AmarMahal Chembur ' 'Tagore Nagar Udyaan Vikroli '
#  'Tagore Nagar Post office' 'Keva Fragnans ' 'Glass Factory '
#  'Bhatiawadi Road' 'Zynova Shalby Hospital ' 'Kamgar Nagr '
#  'Khernagar Road no. 02' 'Sant Mukta Bai Road' 'Nirmal Life style '
#  'RTO office']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution for each numerical feature
numerical_columns = ["Traffic Volume", "Average Speed", "Travel Time Index", "Congestion Level",
                     "Road Capacity Utilization", "Incident Reports", "Environmental Impact", 
                     "Public Transport Usage", "Traffic Signal Compliance", "Parking Usage", 
                     "Pedestrian and Cyclist Count"]

plt.figure(figsize=(16, 12))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Plot a heatmap of correlations
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# Boxplot of 'Traffic Volume' across different 'Weather Conditions'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Weather Conditions', y='Traffic Volume', data=df)
plt.title('Traffic Volume across Weather Conditions')
plt.xticks(rotation=45)
plt.show()

# Similar plot for 'Road/Intersection Name'
plt.figure(figsize=(12, 6))
sns.boxplot(x='Road/Intersection Name', y='Traffic Volume', data=df)
plt.title('Traffic Volume across Road/Intersection Name')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Plot Traffic Volume over time
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
plt.figure(figsize=(14, 6))
plt.plot(df['Date'], df['Traffic Volume'], label='Traffic Volume')
plt.title('Traffic Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Average Traffic Volume by Day of Week
df['Day of Week'] = df['Date'].dt.dayofweek  
avg_traffic_by_day = df.groupby('Day of Week')['Traffic Volume'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=avg_traffic_by_day.index, y=avg_traffic_by_day.values)
plt.title('Average Traffic Volume by Day of Week')
plt.xlabel('Day of Week (0=Mon, 6=Sun)')
plt.ylabel('Average Traffic Volume')
plt.show()

# %%
# Compare Traffic Volume based on roadwork and construction activity
plt.figure(figsize=(10, 6))
sns.boxplot(x='Roadwork and Construction Activity', y='Traffic Volume', data=df)
plt.title('Impact of Roadwork and Construction on Traffic Volume')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Use boxplot to visualize outliers in numerical features
plt.figure(figsize=(14, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(df[col])
    plt.title(f'Outliers in {col}')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
