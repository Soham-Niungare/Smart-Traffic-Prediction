# %%
import pandas as pd

# %%
df = pd.read_csv('Data/Traffic_Data_5.csv')

# %%
df.head()
# Out:
#          Date Road/Intersection Name  Traffic Volume  Average Speed  \
# 0  01-01-2022                    NaN        0.669419       0.392949
# 1  01-01-2022              CST Road         0.775431       0.000000
# 2  01-01-2022     Road no. 01, TPS V        0.632111       0.000000
# 3  01-01-2022   Vakola Pipeline Road        0.456201       0.598162
# 4         NaN        St Anthony Road        0.234796       0.000000
#
#    Travel Time Index  Congestion Level  Road Capacity Utilization  \
# 0                NaN          0.261627                   0.844939
# 1           0.536212          0.615160                   0.035331
# 2           0.969972          0.673203                   0.975692
# 3                NaN          0.259642                   0.345587
# 4           0.622437               NaN                   0.663442
#
#    Incident Reports  Environmental Impact  Public Transport Usage  \
# 0               0.6              0.520505                0.482751
# 1               0.8              0.137807                0.394751
# 2               NaN              0.478489                0.071569
# 3               0.4              0.271353                     NaN
# 4               0.8              0.470199                0.003909
#
#    Pedestrian and Cyclist Count Weather Conditions  \
# 0                      0.601266               Mild
# 1                      0.588608               Mild
# 2                      0.468354               Mild
# 3                      0.392405                NaN
# 4                      0.215190               Mild
#
#    Roadwork and Construction Activity
# 0                                 1.0
# 1                                 1.0
# 2                                 0.0
# 3                                 0.0
# 4                                 0.0

# %%
print(df.describe())
# Out:
#        Traffic Volume  Average Speed  Travel Time Index  Congestion Level  \
# count    95837.000000   95819.000000       95705.000000      95801.000000
# mean         0.526741       0.113058           0.486112          0.554224
# std          0.196098       0.190125           0.208540          0.261997
# min          0.000000       0.000000           0.000000          0.000000
# 25%          0.371986       0.000000           0.334179          0.337203
# 50%          0.526842       0.000000           0.486147          0.558979
# 75%          0.682344       0.176083           0.638526          0.778259
# max          1.000000       1.000000           1.000000          1.000000
#
#        Road Capacity Utilization  Incident Reports  Environmental Impact  \
# count               95764.000000      95841.000000          95632.000000
# mean                    0.499977          0.449989              0.291229
# std                     0.289019          0.296218              0.150401
# min                     0.000000          0.000000              0.000000
# 25%                     0.250015          0.200000              0.165292
# 50%                     0.500805          0.400000              0.290083
# 75%                     0.749476          0.800000              0.415402
# max                     1.000000          1.000000              1.000000
#
#        Public Transport Usage  Pedestrian and Cyclist Count  \
# count            95850.000000                  96003.000000
# mean                 0.499108                      0.498989
# std                  0.290040                      0.213655
# min                  0.000000                      0.000000
# 25%                  0.246426                      0.335443
# 50%                  0.499343                      0.500000
# 75%                  0.751471                      0.658228
# max                  1.000000                      1.000000
#
#        Roadwork and Construction Activity
# count                        95735.000000
# mean                             0.500099
# std                              0.500003
# min                              0.000000
# 25%                              0.000000
# 50%                              1.000000
# 75%                              1.000000
# max                              1.000000

# %%
df.shape
# Out:
# (105850, 13)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105850 entries, 0 to 105849
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                95789 non-null  object
#  1   Road/Intersection Name              95704 non-null  object
#  2   Traffic Volume                      95837 non-null  float64
#  3   Average Speed                       95819 non-null  float64
#  4   Travel Time Index                   95705 non-null  float64
#  5   Congestion Level                    95801 non-null  float64
#  6   Road Capacity Utilization           95764 non-null  float64
#  7   Incident Reports                    95841 non-null  float64
#  8   Environmental Impact                95632 non-null  float64
#  9   Public Transport Usage              95850 non-null  float64
#  10  Pedestrian and Cyclist Count        96003 non-null  float64
#  11  Weather Conditions                  95690 non-null  object
#  12  Roadwork and Construction Activity  95735 non-null  float64
# dtypes: float64(10), object(3)
# memory usage: 10.5+ MB
# None

# %%
df.isnull().sum()
# Out:
# Date                                  10061
# Road/Intersection Name                10146
# Traffic Volume                        10013
# Average Speed                         10031
# Travel Time Index                     10145
# Congestion Level                      10049
# Road Capacity Utilization             10086
# Incident Reports                      10009
# Environmental Impact                  10218
# Public Transport Usage                10000
# Pedestrian and Cyclist Count           9847
# Weather Conditions                    10160
# Roadwork and Construction Activity    10115
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df['Traffic Volume'] = df['Traffic Volume'].interpolate(method='linear')

# %%
df['Weather Conditions'].fillna(df['Weather Conditions'].mode()[0], inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\1055074250.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Weather Conditions'].fillna(df['Weather Conditions'].mode()[0], inplace=True)

# %%
df['Average Speed'].fillna(df['Average Speed'].mean(), inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\2525100194.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Average Speed'].fillna(df['Average Speed'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                                  10061
# Road/Intersection Name                10146
# Traffic Volume                            0
# Average Speed                             0
# Travel Time Index                     10145
# Congestion Level                      10049
# Road Capacity Utilization             10086
# Incident Reports                      10009
# Environmental Impact                  10218
# Public Transport Usage                10000
# Pedestrian and Cyclist Count           9847
# Weather Conditions                        0
# Roadwork and Construction Activity    10115
# dtype: int64

# %%
df['Date'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\3572410786.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Date'].fillna(method='ffill', inplace=True)
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\3572410786.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Date'].fillna(method='ffill', inplace=True)

# %%
df['Road/Intersection Name'].fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\782937216.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Road/Intersection Name'].fillna(method='ffill', inplace=True)
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\782937216.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Road/Intersection Name'].fillna(method='ffill', inplace=True)

# %%
df['Travel Time Index'] = df['Travel Time Index'].interpolate(method='linear')

# %%
df['Congestion Level'] = df['Congestion Level'].interpolate(method='linear')

# %%
df['Road Capacity Utilization'] = df['Road Capacity Utilization'].interpolate(method='linear')

# %%
df['Incident Reports'].fillna(df['Incident Reports'].mode()[0], inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\3827230808.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Incident Reports'].fillna(df['Incident Reports'].mode()[0], inplace=True)

# %%
df['Environmental Impact'] = df['Environmental Impact'].interpolate(method='linear')

# %%
df['Public Transport Usage'] = df['Public Transport Usage'].fillna(df['Public Transport Usage'].rolling(7, min_periods=1).mean())

# %%
df['Pedestrian and Cyclist Count'] = df['Pedestrian and Cyclist Count'].interpolate(method='linear')

# %%
df['Roadwork and Construction Activity'].fillna(df['Roadwork and Construction Activity'].mode()[0], inplace=True)
# Out:
# C:\Users\Soham\AppData\Local\Temp\ipykernel_12756\3203251860.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Roadwork and Construction Activity'].fillna(df['Roadwork and Construction Activity'].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# Date                                  0
# Road/Intersection Name                1
# Traffic Volume                        0
# Average Speed                         0
# Travel Time Index                     1
# Congestion Level                      0
# Road Capacity Utilization             0
# Incident Reports                      0
# Environmental Impact                  0
# Public Transport Usage                0
# Pedestrian and Cyclist Count          0
# Weather Conditions                    0
# Roadwork and Construction Activity    0
# dtype: int64

# %% [markdown]
# ## DATA Exploring

# %%
print(df['Weather Conditions'].unique())
# Out:
# ['Mild' 'Clear' 'Fog' 'Hot and Humid' 'Heatwave' 'Rainy' 'Thunderstorm']

# %%
print(df['Road/Intersection Name'].nunique())
print(df['Road/Intersection Name'].unique())
# Out:
# 283
# [nan 'CST Road ' 'Road no. 01, TPS V' 'Vakola Pipeline Road'
#  'St Anthony Road' 'Mahalaxmi Mandir Road' 'Rajendra Kamble Road'
#  "Sant Mary's Road" 'Chetana College Road' 'New English School Marg'
#  'Samaj Mandir Hall Marg' 'J L Shirshekar Marg' 'Road no. 07, TPS III'
#  'Road No. 06, TPS III' 'Road No. 04, TPS III' 'Road no. 11, TPS V'
#  'Ram Mandir Road' 'Khar Pipeline Road' 'Aaram Society Road'
#  'Side strips of Jawaharlal Nehru Road' 'Vijay Nagar Road'
#  'Parshiwadi Road' 'Manipada Road' 'Shardadevi Marg'
#  'Road no. 08, TPS III' 'Takshila Marg' 'Dnyaneshwar Mandir Marg'
#  'Abbasaheb Shinde Marg' 'Sunder Nagar Road no. 01'
#  'Sunder Nagar Road no. 02' 'Sunder Nagar Road no. 03'
#  'Ramanath Parkar Marg' 'Khernagar Road no. 01' 'Khernagar Road no. 02'
#  'Khernagar Road no. 03' 'Khernagar Road no. 04' 'Khernagar Road no. 06'
#  'Khernagar Road no. 07' 'Khernagar Road no. 08' 'Bhai Tambe Marg'
#  'V.M. Bhargav Road' 'Sidestrip of Juhu Road' 'SS of Kanubhai Desai Marg'
#  '11th Road, Khar West ' 'Gurugangeshwar Road' '10th Road'
#  'Main Avenue Road' 'R K Mission Road' 'S B Patil Road , Khar (W)'
#  '30th Road' '24th Road(St Theresa Road)' '3rd road (Y Shape)'
#  'Turner Road-R K Patkar Road Junction'
#  'Tiurner Road- Ambedkar Road Junction' '2nd Hasnabad Road'
#  'Dr Peter Dias Road' 'Slaughter House Road' '14th Road, Bandra (W)'
#  '12th Road' 'Side Strip of Dr Ambedkar road'
#  'Side Strip of Manuel Gonsalves Road' 'Side Strip C D Road'
#  '14th Road Khar' '27th Road' '28th Road' 'National Library Road'
#  'Jain Derasar Road' 'Pali Mala Road' '16th Road Khar West' '15th road'
#  'M G Road ' '7th road, Khar' 'Talmiki Road ' 'P M Road' 'Saibaba Marg'
#  'St. Andrews Road Extention ' 'Anthony Road' 'St. John Road Extention'
#  ' SS Waterfield Road' 'Juhu Road Link Road Junction' '13th Road'
#  'Dattatray Road' 'Poddar Road' '5th Rd(Khar)' 'John Baptista Road'
#  'Jari Mari Road' 'V M Bhargav Cross road' '1st Road(IPS) '
#  'Dr Ambedkar Road ' 'West Avenue' 'Cyril Rd Exten' 'SS 33rd Road'
#  'St Martin road' 'SS  of RK Mission Road ' 'Centrel Avenue'
#  'SS Relief Road ' 'Tarun Bharat Road' 'Off Nehru Road' 'Dixit Road'
#  'Malviya Cross Road ' 'Sant Mukta Bai Road' 'Chimat Pada Road'
#  'Parleshwar Road' 'Prarthana Samaj Cross Road '
#  'Dayaldas Main Road ( Part 1)' 'Dayaldas Main Road ( Part 2)'
#  'Parshiwadi Cemetry Road' 'Lelewadi Road' 'Nicolaswadi  Rd Side strip'
#  'N S Phadke Marg ( Side Strip)' 'MIDC A Cross Road ' 'Midc Road No. 11'
#  'N P Thakkar Road' 'Veer Makrand Ghanekar Marg'
#  'Baji Prabhu Deshpande Marg' 'Sahakar Road' 'Jeevan Vikas Kendra Marg'
#  'G. B. Indulakar Marg' 'Nanda Patkar Marg' 'Rammandir  Road Vile Parle'
#  'Tilak Mandir Road Vile Parle' 'Sant janabai X Road' 'Kanoji Angre Marg'
#  'Sant Chokha Mela Marg' 'Charatsingh Colony ' 'off Military Road '
#  'Mongibai Road Vile Parle' 'MIDC Road no 7' 'Subhash cross Road'
#  'Sai Nagar Road' 'Ramabai Chemburkar Marg' 'Tilak Vidyalaya Road'
#  'Tejpal Scheme Road no 2' 'Tejpal Scheme Road no 3' 'Thanawala lane'
#  'Sahar Road Side Strip' 'Subhash Road Side Strip'
#  'Play Ground Road Vile Parle' 'Nariman cross Road' 'Wadarwada Road'
#  'M.G.Road side strip' 'Jiva Mahale Marg Side strip '
#  'Shahaji Raje Marg Side strip' 'Jogeshwari Gumpha road'
#  'Church Road (Main)' 'Rane Bunglow junction Road'
#  'Road from Mogaveera Bank to Moonlight Dairy' 'Manjrekar wadi Road'
#  'Subhash Nagar 13.40 m D.P.Road Jogeshwari'
#  'Road from Infant School to Apna Ghar Society' 'Mahakali Caves Road'
#  'Dattaram Waikar Marg' 'R K Singh Road' 'Natwar Nagar Road no 5'
#  'Natwar nagar Road no 1' 'Guru Govind Singh Road ( Roof Top Society)'
#  'New Nagardas Road ' 'Telly Gully Cross Road' 'Bima Nagar Road'
#  'Kondivita Road' 'MIDC Road no 16' 'MIDC Road no 14' 'Kadamwadi Road'
#  'Azad Road,Verma Nagar Road Gundavli' 'Amartaru Road'
#  'Mogra Service Road' 'Marol Maroshi Road'
#  'Sarvodaya nagar Road,Guru Govind singh Road ' 'Extension'
#  'A N Tiwari Road' 'Gaonthan Road Marol' 'Lok Rounak Road Marol'
#  'S.R. Mahadik Road' 'Pimpleshwar Mahadev Mandir Marg'
#  'Jogeshwari Gunfa Road Side strip' 'Shivneri Vasahat cross Road'
#  'Mulund BMC Garden Lane ' 'Duncan Company ' 'Mulund Goregaon Link Road'
#  'Shreyas Signal ' 'Anil Kumble Circle' 'AmarMahal Chembur '
#  'Tagore Nagar Udyaan Vikroli ' 'Tagore Nagar Post office'
#  'G R jolly marg ' 'Ankur Hospital ' '100 Feet Road' 'Crompton Greaves'
#  'Bhandup Station East ' 'Nahur Railway Station East' 'Hema Park'
#  ' Goregaon Link Road' 'Merind Company ' 'Hebbal Flyover'
#  'Fortis Hospital ' 'Dr K B Hedgewar Chowk ' 'Nirmal Life style '
#  'Ralli wolf ' 'Johnson and Johnson Company ' 'ESIS Hospital '
#  'Govardhan Nagar' 'Maharana Pratap chowk ' 'Kisan Nagar junction '
#  'Wagle Circle ' 'Dnyan Sarita Thane' 'Marathahalli Bridge' 'pipe line '
#  'Post and Telegraphs ' 'Vidyaben Gardi School Keshavpada'
#  'Kalidas natyagruh' 'Maharishi Arvind Chowk '
#  'Agarwal Municipal hospital ' 'Veena Nagar ' 'Guru Nanak Nagar '
#  'Chirag nagar ' 'Laxmi Nagar ' 'Pantnagar '
#  'Jija mata bhosle marg junction ' 'RTO office' 'Sarvodaya Hospital '
#  'Gopal Bhavan ' 'Nityanand Nagar ' 'Amar Mahal ' 'Glass Factory '
#  'Somaiya College ' 'Sindhuwadi ' 'Rajawadi Hospital ' 'Gandhi market '
#  'Old Agra Road ' 'Sheetal Cinema ' 'State Bank kamani ' 'PWD office'
#  'Narayan Nagar ' 'Bhatiawadi Road' 'Phoenix Market city ' 'Jarimari '
#  'Chandivali ' 'Saikana Bus Station' 'Andheri-Ghatkopar link rd'
#  'bhatwadi ' 'Maneklal Estate ' 'KajuPada' '90 feet road' 'Shivaji Nagar'
#  'KajuPada pipeline road' 'Agastya Corporate Park '
#  'Piramal Reality Estate ' 'Zynova Shalby Hospital ' 'Jagdusha Nagar '
#  'Hingwala Lane ' 'Lavender Baug ' 'Garodia Ngar ' 'Tilak Nagar'
#  'Ambedkar Garden ' 'Eastern Express Freeway ' 'Express Highway '
#  'Postal Colony ' 'SG Barve Road Junction ' 'Thakkar Bappa Colony '
#  'Kamgar Nagr ' 'Nehru Nagr ' 'Kalina Kurla Road' 'Military Camp Road'
#  'Chhatrapati Shivaji Maharaj Road Extn.' '14th B Road, Khar(W)'
#  'SS of K C Marg' 'St Peter Road' 'New Kantwadi Road'
#  '17th Road (Santacruz)' 'East Avenue' 'MIDC B X Road'
#  'Old Nagardas Rd Side strip' 'Sadbhakiti road '
#  'MIDC road no 23 (Ext. C x Road)' 'Trinity Circle' 'Wagle Ward Committee'
#  'Keva Fragnans ' 'Gyan Sarita School ' 'Kadam Pada' 'Mukund company '
#  'Pestam Sagar ' 'Azad Nagar ' 'Road No 5, Rizvi complex'
#  'Mulund Railway Station West ']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot distribution for each numerical feature
numerical_columns = ["Traffic Volume", "Average Speed", "Travel Time Index", "Congestion Level",
                     "Road Capacity Utilization", "Incident Reports", "Environmental Impact", 
                     "Public Transport Usage",  
                     "Pedestrian and Cyclist Count"]

plt.figure(figsize=(16, 12))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Compute the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Plot a heatmap of correlations
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
# Boxplot of 'Traffic Volume' across different 'Weather Conditions'
plt.figure(figsize=(10, 6))
sns.boxplot(x='Weather Conditions', y='Traffic Volume', data=df)
plt.title('Traffic Volume across Weather Conditions')
plt.xticks(rotation=45)
plt.show()

# Similar plot for 'Road/Intersection Name'
plt.figure(figsize=(12, 6))
sns.boxplot(x='Road/Intersection Name', y='Traffic Volume', data=df)
plt.title('Traffic Volume across Road/Intersection Name')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Plot Traffic Volume over time
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y')
plt.figure(figsize=(14, 6))
plt.plot(df['Date'], df['Traffic Volume'], label='Traffic Volume')
plt.title('Traffic Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Traffic Volume')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# Average Traffic Volume by Day of Week
df['Day of Week'] = df['Date'].dt.dayofweek  
avg_traffic_by_day = df.groupby('Day of Week')['Traffic Volume'].mean()

plt.figure(figsize=(10, 6))
sns.barplot(x=avg_traffic_by_day.index, y=avg_traffic_by_day.values)
plt.title('Average Traffic Volume by Day of Week')
plt.xlabel('Day of Week (0=Mon, 6=Sun)')
plt.ylabel('Average Traffic Volume')
plt.show()

# %%
# Compare Traffic Volume based on roadwork and construction activity
plt.figure(figsize=(10, 6))
sns.boxplot(x='Roadwork and Construction Activity', y='Traffic Volume', data=df)
plt.title('Impact of Roadwork and Construction on Traffic Volume')
plt.xticks([0, 1], ['No', 'Yes'])
plt.show()
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Use boxplot to visualize outliers in numerical features
plt.figure(figsize=(14, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(4, 3, i)
    sns.boxplot(df[col])
    plt.title(f'Outliers in {col}')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# ### Outliers (by inter quartile range [IQR] method)

# %% [markdown]
# #### Average Speed

# %%
sns.boxplot(df['Average Speed'])
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Average Speed'>

# %%
q1 = df['Average Speed'].quantile(0.25)
q3 = df['Average Speed'].quantile(0.75)

# %%
iqr = q3-q1

# %%
q1,q3,iqr
# Out:
# (0.0, 0.14220022021360723, 0.14220022021360723)

# %%
upper_limit=  q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (-0.21330033032041085, 0.3555005505340181)

# %%
df.loc[(df['Average Speed'] > upper_limit) | (df['Average Speed'] < lower_limit)]
# Out:
#              Date   Road/Intersection Name  Traffic Volume  Average Speed  \
# 0      2022-01-01                      NaN        0.669419       0.392949
# 3      2022-01-01     Vakola Pipeline Road        0.456201       0.598162
# 6      2022-01-01     Rajendra Kamble Road        0.491854       0.637415
# 10     2022-01-01   Samaj Mandir Hall Marg        0.184747       0.396537
# 14     2022-01-01     Road No. 04, TPS III        0.749203       0.941859
# ...           ...                      ...             ...            ...
# 105757 2022-12-31       Anil Kumble Circle        0.379316       0.396715
# 105758 2022-12-31       Anil Kumble Circle        0.385450       0.516097
# 105817 2022-12-31           Narayan Nagar         0.579530       0.390995
# 105831 2022-12-31            Shivaji Nagar        0.778313       0.418924
# 105834 2022-12-31  Piramal Reality Estate         0.582336       0.356047
#
#         Travel Time Index  Congestion Level  Road Capacity Utilization  \
# 0                     NaN          0.261627                   0.844939
# 3                0.796204          0.259642                   0.345587
# 6                0.191299          0.322178                   0.479359
# 10               0.353308          0.600711                   0.814397
# 14               0.526468          0.025959                   0.521625
# ...                   ...               ...                        ...
# 105757           0.408613          0.295784                   0.047697
# 105758           0.195930          0.330141                   0.741184
# 105817           0.329984          0.360607                   0.970478
# 105831           0.302727          0.397673                   0.363828
# 105834           0.083559          0.136947                   0.538540
#
#         Incident Reports  Environmental Impact  Public Transport Usage  \
# 0                    0.6              0.520505                0.482751
# 3                    0.4              0.271353                0.316357
# 6                    0.0              0.507745                0.568500
# 10                   0.0              0.352446                0.500789
# 14                   0.0              0.106532                0.914565
# ...                  ...                   ...                     ...
# 105757               1.0              0.229581                0.326385
# 105758               0.0              0.418285                0.017202
# 105817               0.4              0.416064                0.963962
# 105831               0.4              0.573476                0.008256
# 105834               0.0              0.492675                0.671648
#
#         Pedestrian and Cyclist Count Weather Conditions  \
# 0                           0.601266               Mild
# 3                           0.392405               Mild
# 6                           0.272152               Mild
# 10                          0.259494               Mild
# 14                          0.822785               Mild
# ...                              ...                ...
# 105757                      0.556962              Clear
# 105758                      0.408228              Clear
# 105817                      0.569620              Clear
# 105831                      0.278481              Clear
# 105834                      0.481013              Clear
#
#         Roadwork and Construction Activity  Day of Week
# 0                                      1.0            5
# 3                                      0.0            5
# 6                                      0.0            5
# 10                                     1.0            5
# 14                                     1.0            5
# ...                                    ...          ...
# 105757                                 1.0            5
# 105758                                 1.0            5
# 105817                                 1.0            5
# 105831                                 0.0            5
# 105834                                 0.0            5
#
# [12596 rows x 14 columns]

# %%
new_df = df.loc[(df['Average Speed'] < upper_limit) & (df['Average Speed'] > lower_limit)]
print('before removing outliers: ' , len(df))
print('after removing outliers: ', len(new_df))
print('outliers:' ,len(df) - len(new_df))
# Out:
# before removing outliers:  105850
# after removing outliers:  93254
# outliers: 12596

# %%
sns.boxplot(new_df['Average Speed'])
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Average Speed'>

# %%
# capping - change the outlier values to upper (or) lower limit
new_df = df.copy()
new_df.loc[(new_df['Average Speed']>upper_limit), 'Average Speed'] = upper_limit
new_df.loc[(new_df['Average Speed']<lower_limit), 'Average Speed'] = lower_limit

# %%
sns.boxplot(new_df['Average Speed'])
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Average Speed'>

# %% [markdown]
# #### Environmental Impact

# %%
sns.boxplot(df['Environmental Impact'])
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Environmental Impact'>

# %%
q1 = df['Environmental Impact'].quantile(0.25)
q3 = df['Environmental Impact'].quantile(0.75)

# %%
iqr = q3-q1

# %%
q1,q3,iqr
# Out:
# (0.1711724124846106, 0.4102696456744316, 0.23909723318982098)

# %%
upper_limit=  q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)
lower_limit, upper_limit
# Out:
# (-0.18747343730012087, 0.768915495459163)

# %%
df.loc[(df['Environmental Impact'] > upper_limit) | (df['Environmental Impact'] < lower_limit)]
# Out:
#              Date    Road/Intersection Name  Traffic Volume  Average Speed  \
# 290    2022-01-02         Kalina Kurla Road        0.122488       0.184771
# 606    2022-01-03      Road no. 08, TPS III        0.275720       0.113058
# 1255   2022-01-05    V M Bhargav Cross road        0.170245       0.000000
# 2207   2022-01-08            Kadamwadi Road        0.106737       0.000000
# 2930   2022-01-11  Sunder Nagar Road no. 01        0.358309       0.113058
# ...           ...                       ...             ...            ...
# 103682 2022-12-24       M.G.Road side strip        0.286823       0.166216
# 103996 2022-12-25           MIDC Road no 16        0.267145       0.000000
# 104012 2022-12-25   Mulund BMC Garden Lane         0.195623       0.772942
# 104738 2022-12-28                 10th Road        0.422514       0.822231
# 105663 2022-12-31       16th Road Khar West        0.193503       0.166006
#
#         Travel Time Index  Congestion Level  Road Capacity Utilization  \
# 290              0.614688          0.650078                   0.677562
# 606              0.215085          0.163066                   0.600543
# 1255             0.300183          0.509377                   0.806762
# 2207             0.899354          0.573766                   0.617798
# 2930             0.245334          0.215073                   0.009302
# ...                   ...               ...                        ...
# 103682           0.132339          0.120810                   0.083639
# 103996           0.417736          0.611476                   0.001750
# 104012           0.096234          0.158739                   0.213549
# 104738           0.302779          0.068993                   0.055887
# 105663           0.218941          0.269699                   0.692742
#
#         Incident Reports  Environmental Impact  Public Transport Usage  \
# 290                  0.6              0.988860                0.553826
# 606                  0.4              0.856472                0.862032
# 1255                 0.0              0.978956                0.819801
# 2207                 0.8              0.778408                0.919108
# 2930                 0.6              0.938642                0.402274
# ...                  ...                   ...                     ...
# 103682               0.4              0.956927                0.425310
# 103996               0.2              0.971706                0.598857
# 104012               0.0              0.884317                0.779481
# 104738               0.0              0.989953                0.609578
# 105663               0.4              0.815771                0.247773
#
#         Pedestrian and Cyclist Count Weather Conditions  \
# 290                         0.531646              Clear
# 606                         0.936709               Mild
# 1255                        0.822785               Mild
# 2207                        0.917722               Mild
# 2930                        0.303797               Mild
# ...                              ...                ...
# 103682                      0.449367               Mild
# 103996                      0.272152               Mild
# 104012                      0.829114               Mild
# 104738                      0.696203              Clear
# 105663                      0.170886              Clear
#
#         Roadwork and Construction Activity  Day of Week
# 290                                    1.0            6
# 606                                    1.0            0
# 1255                                   0.0            2
# 2207                                   1.0            5
# 2930                                   1.0            1
# ...                                    ...          ...
# 103682                                 0.0            5
# 103996                                 0.0            6
# 104012                                 0.0            6
# 104738                                 1.0            2
# 105663                                 1.0            5
#
# [148 rows x 14 columns]

# %%
new_df = df.loc[(df['Environmental Impact'] < upper_limit) & (df['Environmental Impact'] > lower_limit)]
print('before removing outliers: ' , len(df))
print('after removing outliers: ', len(new_df))
print('outliers:' ,len(df) - len(new_df))
# Out:
# before removing outliers:  105850
# after removing outliers:  105702
# outliers: 148

# %%
sns.boxplot(new_df['Environmental Impact'])
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: ylabel='Environmental Impact'>

# %% [markdown]
# # Feature Engineering

# %%
df.head()
# Out:
#         Date Road/Intersection Name  Traffic Volume  Average Speed  \
# 0 2022-01-01                    NaN        0.669419       0.392949
# 1 2022-01-01              CST Road         0.775431       0.000000
# 2 2022-01-01     Road no. 01, TPS V        0.632111       0.000000
# 3 2022-01-01   Vakola Pipeline Road        0.456201       0.598162
# 4 2022-01-01        St Anthony Road        0.234796       0.000000
#
#    Travel Time Index  Congestion Level  Road Capacity Utilization  \
# 0                NaN          0.261627                   0.844939
# 1           0.536212          0.615160                   0.035331
# 2           0.969972          0.673203                   0.975692
# 3           0.796204          0.259642                   0.345587
# 4           0.622437          0.377791                   0.663442
#
#    Incident Reports  Environmental Impact  Public Transport Usage  \
# 0               0.6              0.520505                0.482751
# 1               0.8              0.137807                0.394751
# 2               0.4              0.478489                0.071569
# 3               0.4              0.271353                0.316357
# 4               0.8              0.470199                0.003909
#
#    Pedestrian and Cyclist Count Weather Conditions  \
# 0                      0.601266               Mild
# 1                      0.588608               Mild
# 2                      0.468354               Mild
# 3                      0.392405               Mild
# 4                      0.215190               Mild
#
#    Roadwork and Construction Activity  Day of Week
# 0                                 1.0            5
# 1                                 1.0            5
# 2                                 0.0            5
# 3                                 0.0            5
# 4                                 0.0            5

# %%
df = df.drop('Road Capacity Utilization', axis=1)

# %%
df.head()
# Out:
#         Date Road/Intersection Name  Traffic Volume  Average Speed  \
# 0 2022-01-01                    NaN        0.669419       0.392949
# 1 2022-01-01              CST Road         0.775431       0.000000
# 2 2022-01-01     Road no. 01, TPS V        0.632111       0.000000
# 3 2022-01-01   Vakola Pipeline Road        0.456201       0.598162
# 4 2022-01-01        St Anthony Road        0.234796       0.000000
#
#    Travel Time Index  Congestion Level  Incident Reports  \
# 0                NaN          0.261627               0.6
# 1           0.536212          0.615160               0.8
# 2           0.969972          0.673203               0.4
# 3           0.796204          0.259642               0.4
# 4           0.622437          0.377791               0.8
#
#    Environmental Impact  Public Transport Usage  Pedestrian and Cyclist Count  \
# 0              0.520505                0.482751                      0.601266
# 1              0.137807                0.394751                      0.588608
# 2              0.478489                0.071569                      0.468354
# 3              0.271353                0.316357                      0.392405
# 4              0.470199                0.003909                      0.215190
#
#   Weather Conditions  Roadwork and Construction Activity  Day of Week
# 0               Mild                                 1.0            5
# 1               Mild                                 1.0            5
# 2               Mild                                 0.0            5
# 3               Mild                                 0.0            5
# 4               Mild                                 0.0            5

# %% [markdown]
# ### Categorical Variable Transformation

# %%
df = pd.get_dummies(df, columns=['Weather Conditions'], drop_first=True)

# %% [markdown]
# ### Normalize/Standardize Numerical Features

# %%
from sklearn.preprocessing import MinMaxScaler

# List of numerical columns
numerical_columns = [
    "Traffic Volume", "Average Speed", "Travel Time Index", 
    "Congestion Level", "Incident Reports", 
    "Environmental Impact", "Public Transport Usage", 
    "Pedestrian and Cyclist Count", "Roadwork and Construction Activity"
]

# Initialize the scaler
scaler = MinMaxScaler()

# Apply scaling
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# %% [markdown]
# ### Time Series Transformation

# %%
# Create lag feature for Traffic Volume (previous day's traffic volume)
df['Traffic_Volume_Lag_1'] = df['Traffic Volume'].shift(1)

# %% [markdown]
# # Create Train-Test Split

# %%
from sklearn.model_selection import train_test_split

# Drop NaN values
df.dropna(inplace=True)

# Create a chronological split
train_size = int(len(df) * 0.8)  # 80% for training
train, test = df.iloc[:train_size], df.iloc[train_size:]

# Further split the training set for validation if necessary
from sklearn.model_selection import train_test_split
train, val = train_test_split(train, test_size=0.2, shuffle=False)

# %% [markdown]
# # Baseline Model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Define features and target variable
features = [
    "Average Speed", "Travel Time Index", "Congestion Level", 
    "Incident Reports", "Environmental Impact", 
    "Public Transport Usage", "Pedestrian and Cyclist Count", 
    "Roadwork and Construction Activity", "Day of Week", 
    "Traffic_Volume_Lag_1"  # Include lag feature
]
target = "Traffic Volume"

# %%
# Separate the features and target for training and validation sets
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]

# %%
# Initialize the model
model = LinearRegression()

# %%
# Fit the model on the training set
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the validation set
y_pred = model.predict(X_val)

# %%
# Evaluate the model
rmse = mean_squared_error(y_val, y_pred, squared=False)
mae = mean_absolute_error(y_val, y_pred)
# Out:
# C:\Users\Soham\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
# Out:
# RMSE: 0.1835489754597512
# MAE: 0.15362338893248254

# %%
df.head()
# Out:
#         Date Road/Intersection Name  Traffic Volume  Average Speed  \
# 1 2022-01-01              CST Road         0.775431       0.000000
# 2 2022-01-01     Road no. 01, TPS V        0.632111       0.000000
# 3 2022-01-01   Vakola Pipeline Road        0.456201       0.598162
# 4 2022-01-01        St Anthony Road        0.234796       0.000000
# 5 2022-01-01  Mahalaxmi Mandir Road        0.363325       0.298971
#
#    Travel Time Index  Congestion Level  Incident Reports  \
# 1           0.536212          0.615160               0.8
# 2           0.969972          0.673203               0.4
# 3           0.796204          0.259642               0.4
# 4           0.622437          0.377791               0.8
# 5           0.466867          0.495939               0.6
#
#    Environmental Impact  Public Transport Usage  Pedestrian and Cyclist Count  \
# 1              0.137807                0.394751                      0.588608
# 2              0.478489                0.071569                      0.468354
# 3              0.271353                0.316357                      0.392405
# 4              0.470199                0.003909                      0.215190
# 5              0.245352                0.675474                      0.810127
#
#    Roadwork and Construction Activity  Day of Week  Weather Conditions_Fog  \
# 1                                 1.0            5                   False
# 2                                 0.0            5                   False
# 3                                 0.0            5                   False
# 4                                 0.0            5                   False
# 5                                 0.0            5                   False
#
#    Weather Conditions_Heatwave  Weather Conditions_Hot and Humid  \
# 1                        False                             False
# 2                        False                             False
# 3                        False                             False
# 4                        False                             False
# 5                        False                             False
#
#    Weather Conditions_Mild  Weather Conditions_Rainy  \
# 1                     True                     False
# 2                     True                     False
# 3                     True                     False
# 4                     True                     False
# 5                     True                     False
#
#    Weather Conditions_Thunderstorm  Traffic_Volume_Lag_1
# 1                            False              0.669419
# 2                            False              0.775431
# 3                            False              0.632111
# 4                            False              0.456201
# 5                            False              0.234796
